# %%
# !pip install -r requirements.txt
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_md

# %%
import pandas as pd
import re
from EHRExecutor import PatientClusteringProcessor

data_file = 'data/ehr_data.csv'
abbreviations_file = 'abbreviations.json'
processor = PatientClusteringProcessor(data_file, abbreviations_file)
processor.run()
# Out:
# Training data size: 4729
# Testing data size: 1014
# Validation data size: 1014
# Splitting training data, saving to data/train_data.db
# Splitting testing data, saving to data/test_data.db
# Splitting validation data, saving to data/validation_data.db
# Created split
# Processing data/train_data.csv
# Performing KMeans Clustering on 50 clusters...
# Model fitted and saved.
# Clustering execution time:  4.24132513999939
# Processing data/test_data.csv
# Performing KMeans Clustering on 50 clusters...
# Model fitted and saved.
# Clustering execution time:  0.2474977970123291
# Processing data/validate_data.csv
# Performing KMeans Clustering on 50 clusters...
# Model fitted and saved.
# Clustering execution time:  0.3377420902252197
